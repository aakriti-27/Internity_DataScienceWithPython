# %% [markdown]
# **plotly** is an interactive visualization Python library which is used to design graphs, especially interactive graphs. It can plot various graphs and charts like histogram, barplot etc It is mainly used in data analysis as well as financial analysis.<br>
# **Cufflinks** is another library that connects the Pandas data frame with Plotly enabling users to create visualizations directly from Pandas.

# %%
#To install plotly - pip install plotly
#To install cufflinks - pip install cufflinks

import plotly
import cufflinks as cf
import pandas as pd
import numpy as np

#Enabling the offline mode for interactive plotting locally
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()

#To display the plots
# %matplotlib inline

df = pd.DataFrame(np.random.randn(100, 3), columns =['C1','C2','C3'])
df
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df.iplot()   #normal plot
# Out:
# <div>
#
#
#             <div id="2fc371e0-4c14-4c57-9251-bf39577272b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2fc371e0-4c14-4c57-9251-bf39577272b6")) {
#                     Plotly.newPlot(
#                         '2fc371e0-4c14-4c57-9251-bf39577272b6',
# ...

# %%
df.iplot(kind = 'bar', x = 'C1', y = 'C2')  #bar graph
# Out:
# <div>
#
#
#             <div id="124b44d0-454a-4281-8357-2cb7c68d089d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("124b44d0-454a-4281-8357-2cb7c68d089d")) {
#                     Plotly.newPlot(
#                         '124b44d0-454a-4281-8357-2cb7c68d089d',
# ...

# %%
df[['C1','C3']].iplot(kind = 'scatter' , mode = 'markers')  #scatter plot
# Out:
# <div>
#
#
#             <div id="c2eb60d1-4e01-45ee-be8d-fff28da98f49" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c2eb60d1-4e01-45ee-be8d-fff28da98f49")) {
#                     Plotly.newPlot(
#                         'c2eb60d1-4e01-45ee-be8d-fff28da98f49',
# ...

# %%
df.iplot(kind ='box') #box plot
# Out:
# <div>
#
#
#             <div id="c9c04a7c-e4cf-4253-8d23-6939d881e913" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c9c04a7c-e4cf-4253-8d23-6939d881e913")) {
#                     Plotly.newPlot(
#                         'c9c04a7c-e4cf-4253-8d23-6939d881e913',
# ...

# %%
#surface plot
data[['C1','C2','C3']].iplot(kind = 'surface', colorscale = 'blues')  #3D interactive plots.
# Out:
# <div>
#
#
#             <div id="a7b6fa30-a447-462a-8528-6d40272f0f11" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a7b6fa30-a447-462a-8528-6d40272f0f11")) {
#                     Plotly.newPlot(
#                         'a7b6fa30-a447-462a-8528-6d40272f0f11',
#                         [{"colorscale": [[0.0, "rgb(247,251,255)"], [0.125, "rgb(222,235,247)"], [0.25, "rgb(198,219,239)"], [0.375, "rgb(158,202,225)"], [0.5, "rgb(107,174,214)"], [0.625, "rgb(66,146,198)"], [0.75, "rgb(33,113,181)"], [0.875, "rgb(8,81,156)"], [1.0, "rgb(8,48,107)"]], "type": "surface", "x": [0, 1, 2, 3, 4], "y": ["A", "B", "C"], "z": [[1, 5, 7, 8, 2], [10, 23, 56, 45, 98], [21, 65, 34, 45, 32]]}],
# ...
